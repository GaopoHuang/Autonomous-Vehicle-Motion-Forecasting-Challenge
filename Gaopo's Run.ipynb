# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, os.path 
import numpy 
import pickle
from glob import glob
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable


"""Change to the data folder"""
new_path = "../new_train/new_train/"
val_path = "../new_val_in/new_val_in/"

# number of sequences in each dataset
# train:205942  val:3200 test: 36272 
# sequences sampled at 10HZ rate

# %% [markdown]
# ### Create a dataset class

# %%
class ArgoverseDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, data_path: str, training=True):
        super(ArgoverseDataset, self).__init__()
        self.data_path = data_path
        self.training = training

        self.pkl_list = glob(os.path.join(self.data_path, '*'))
        self.pkl_list.sort()
        
    def __len__(self):
        return len(self.pkl_list)

    def __getitem__(self, idx):

        pkl_path = self.pkl_list[idx]
        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

#         varMin =[-5.37872696e+00,  0.00000000e+00, -6.39434204e+01, -8.02092514e+01,
#   0.00000000e+00,  0.00000000e+00,  1.00000000e+06,  1.00000000e+06]
#         varMax = [ 4.72452881e+03,  4.08314209e+03,  7.73842545e+01,  0.00000000e+00,
#   4.73215820e+03,  4.07677856e+03, -1.00000000e+06, -1.00000000e+06]
        columns = ['p_in','p_in','v_in','v_in','lane','lane','lane_norm','lane_norm']
        outColumns = ['p_out','p_out','v_out','v_out']
    #FOR 1000 rows, no shuffle
#     varMin=[ 0.00000000e+00,  0.00000000e+00, -3.83204346e+01, -4.79440918e+01,
#   0.00000000e+00,  0.00000000e+00,  1.00000000e+06,  1.00000000e+06]
#         varMax=[ 4.70824121e+03,  4.04640869e+03,  7.00706635e+01,  0.00000000e+00,
#   4.71727344e+03,  4.07275757e+03, -1.00000000e+06, -1.00000000e+06]
#   FOR ALL ROWS
#         varMaxOutput= [4773.,   4097.7,   193.19,  194.33]
#         varMinOutput=[ -53.912,    0.,    -210.04,  -187.71 ]
#         varMaxInput=[4748.2,   4096.1,    252.32,   183.53,  4791.6,   4121.4,     18.801,   16.702]
#         varMinInput=[ -46.958,    0.,    -222.63,  -179.87,   -75.963,    0.,     -18.564,  -16.691]
#         #Changed to 4 because we don't need lane and lane norm
#         print("here in argo")
#         print("before p_out ",data['p_out'])
#         print("before v_out ",data['v_out'])
#         for i in range(8):
#             j = i % 2
#             data[columns[i]][j] = (data[columns[i]][j] - varMinInput[i]) / (varMaxInput[i] - varMinInput[i])
#             if i < 4 and self.training:
#                 data[outColumns[i]][j] = (data[outColumns[i]][j] - varMinOutput[i]) / (varMaxOutput[i] - varMinOutput[i]) 
#         data['p_out'][0] = (data['p_out'][0] - -5.37872696e+00) / (4.72452881e+03 - -5.37872696e+00)
#         print("after p_out ",data['p_out'])
#         print("after v_out ",data['v_out'])
        return data


train_dataset  = ArgoverseDataset(data_path=new_path)
val_dataset = ArgoverseDataset(data_path=val_path,training=False)
#print((val_dataset[0]))
#print(len(train_dataset[0]))

# %% [markdown]
# ### Create a loader to enable batch processing

# %%
batch_sz = 10

def my_collate(batch):
    """ collate lists of samples into batches, create [ batch_sz x agent_sz x seq_len x feature] """
    inp = []
    out = []
    laneInfo = []
    city = []
#     print("pIn",batch[0]['p_in'])
    numbRows = 60
    for scene in batch:
#         print("scenePin",scene['p_in'])
        cityyy = numpy.zeros((60,1,4))
        #print(cityyy)
        if scene['city'] == 'PIT':
            cityyy[:,:,:] = 1
            #print("mummamia",cityyy)
        city.append(numpy.dstack([cityyy]))
        lanes = numpy.zeros((numbRows * 19,2))
        lane_norm = numpy.zeros((numbRows * 19,2))
#         pIn = numpy.zeros((numbRows,19,2))
#         vIn = numpy.zeros((numbRows,19,2))
        lengthLane = min(numbRows * 19,len(scene['lane']))
#         pIn[:len(scene['p_in']),:,:2] = scene['p_in']
#         vIn[:len(scene['v_in']),:,:2] = scene['v_in']
        
#         x = lanes.reshape()
        lanes[:lengthLane,:2] = scene['lane'][:lengthLane,:2]
        lane_norm[:lengthLane,:2] = scene['lane_norm'] [:lengthLane,:2]
        laneInfo.append(numpy.dstack([lanes.reshape(60,19,2),lane_norm.reshape(60,19,2)]))
        inp.append(numpy.dstack([scene['p_in'],scene['v_in']]))
        out.append(numpy.dstack([scene['p_out'], scene['v_out']]))
#     print("from mycollate",scene['p_in']) 
#     print("p_in",inp[0][0][0])
    laneInfo = torch.FloatTensor(laneInfo)
    inp = torch.FloatTensor(inp)
    out = torch.FloatTensor(out)
    city = torch.FloatTensor(city)
#     print("laneInfor shape: ",laneInfo.shape)
#     print("inp shape: ",inp.shape)
#     print("out shape: ",out.shape)
#     print("city shape: ",city.shape)
    return [city,laneInfo,inp, out]

train_loader = DataLoader(train_dataset,batch_size=batch_sz, shuffle = True, collate_fn=my_collate, num_workers=8)

# %%
batch_sz = 2
def val_collate(batch):
    agentIds = []
    trackIds = []
    sceneIdxs = []
    laneInfo = []
    inp = []
    city = []
    numbRows = 60
    for scene in batch:
        """ collate lists of samples into batches, create [ batch_sz x agent_sz x seq_len x feature] """
        agentIds.append(scene['agent_id'])
        trackIds.append(scene['track_id'])
        sceneIdxs.append(scene['scene_idx'])
        
        cityyy = numpy.zeros((60,1,4))
        #print(cityyy)
        if scene['city'] == 'PIT':
            cityyy[:,:,:] = 1
        city.append(numpy.dstack([cityyy]))
        
        lanes = numpy.zeros((numbRows * 19,2))
        lane_norm = numpy.zeros((numbRows * 19,2))
        lengthLane = min(numbRows * 19,len(scene['lane']))
        lanes[:lengthLane,:2] = scene['lane'][:lengthLane,:2]
        lane_norm[:lengthLane,:2] = scene['lane_norm'] [:lengthLane,:2]
        laneInfo.append(numpy.dstack([lanes.reshape(60,19,2),lane_norm.reshape(60,19,2)]))
        inp.append(numpy.dstack([scene['p_in'], scene['v_in']]))
    inp = torch.FloatTensor(inp)
    laneInfo = torch.FloatTensor(laneInfo)
    city = torch.FloatTensor(city)
    return [inp,sceneIdxs,agentIds,trackIds,laneInfo,city]

val_loader = DataLoader(val_dataset,batch_size=batch_sz, shuffle = False, collate_fn=val_collate, num_workers=6)

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

class FullyConnectedModel(nn.Module):
    def __init__(self):
        super(FullyConnectedModel, self).__init__()
        

        self.hidden_dim = 240*60
        
        self.linear = nn.Sequential(
            nn.Linear(240 * 39, self.hidden_dim),
            nn.ReLU(), 
            nn.Linear(self.hidden_dim,240 * 32),
            nn.ReLU(),
            nn.Linear(240*32, 240*30)
        )
#         self.bn1 = nn.BatchNorm1d(num_features=4)
        
    def forward(self, x):
        x = self.linear(x)

        return x
    
    def forwardTesting(self,x,num_steps=30):
        res =[]
        h = torch.zeros((self.num_layers,len(x),self.hidden_dim)).cuda()
        c = torch.zeros((self.num_layers,len(x),self.hidden_dim)).cuda()
        for steps in range(num_steps):
            x,(h,c) = self.lstm(x,(h,c))
            x = x[:,-1:]
            x = x.transpose(1,2)
            x = self.fc(x)
            x = x.transpose(1,2)
#             print("xxxx " ,x)
            res.append(x)
        res = torch.cat(res,1)
        return res

# %% [markdown]
# ### Training

# %%
from statistics import mean
import random
import numpy as np

torch.cuda.empty_cache()
agent_id = 0
learning_rate = 1e-5
momentum = 0.01
device = torch.device("cuda:0")
input_dim = 4 * 60    # input dimension
hidden_dim = 3000  # hidden layer dimension should be greater when batch_sz small
layer_dim = 3    # number of hidden layers
output_dim = 4   # output dimension
n_epochs = 30

'''Define Loss, Optimizer'''
#model = RNNModel(input_dim, output_dim, hidden_dim, layer_dim).to(device)
model = FullyConnectedModel()
# model.load_state_dict(torch.load('./3000Temp.pth'))
model = model.to(device)
# optimizer = optim.Adagrad(model.parameters(), lr=learning_rate,lr_decay=1e-6,weight_decay=1e-5)
# optimizer = optim.Adadelta(model.parameters())
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-5,amsgrad=True)
# optimizer = optim.RMSprop(model.parameters(),lr=learning_rate,momentum=momentum)

model.train()
print("start")
loss_ema = -1
try:
    for i_epoch in range(n_epochs):
        for i_batch, sample_batch in enumerate(train_loader):
        #     print("test")
            city,laneInfo,inp, out = sample_batch
            laneInfo = laneInfo.cuda()
            inp = inp.cuda()
            out = out.cuda()
            city = city.cuda()
            optimizer.zero_grad()
            mixed = torch.cat([city,laneInfo,inp],2).transpose(1,2).reshape(-1,39,4 * 60).reshape(-1,39*240)
#             print(mixed.shape)
            
            y_pred = model(mixed)
            y_pred = y_pred.reshape((-1,30,60,4)).transpose(1,2)
#             print(y_pred.shape)
#             print("before inverse ",y_pred)
#             print("before inverse ",out[0])
            #THIS IS IF I NORMALIZED, I WANT TO DENORMALIZE OUT AND Y_PRED
#             for i in range(4):
#                 y_pred[:,:,:,i] = (y_pred[:,:,:,i] * (varMaxOutput[i] - varMinOutput[i])) + varMinOutput[i]
#                 out[:,:,:,i] = (out[:,:,:,i] * (varMaxOutput[i] - varMinOutput[i])) + varMinOutput[i]
#             print("after inverse y_pred: ",y_pred[0][0][0][0], " out: ",out[0][0][0][0])

#             print(y_pred.shape)
            
#             print(out.shape)
            #loss = nn.MSELoss()
            #loss = loss(y_pred,out)
#             print(y_pred)
            loss = (torch.mean((y_pred-out)**2))
            loss.backward()
            optimizer.step()
            if loss_ema < 0:
                loss_ema = loss
            loss_ema= loss_ema*0.90 +loss*0.1

            if i_batch % 20 == 0:
                print("epoch#{:d}".format(i_epoch),"batch#{:d}".format(i_batch),"scenes#{:d}".format(i_batch * batch_sz)," avg loss per scene(past 100): ",loss_ema.item(),loss.item())
        torch.save(model.state_dict(), './FCM_Adam_30Epochs_HDim7k_L2.pth')    
except KeyboardInterrupt:
    print("savedModel")
    torch.save(model.state_dict(), './FCM_Adam_30Epochs_HDim7k_l2.pth')
# Out:
# start
# epoch#0 batch#0 scenes#0  avg loss per scene(past 100):  239863.703125 239863.703125
# epoch#0 batch#20 scenes#200  avg loss per scene(past 100):  227730.703125 123027.0
# epoch#0 batch#40 scenes#400  avg loss per scene(past 100):  131954.46875 94597.578125
# epoch#0 batch#60 scenes#600  avg loss per scene(past 100):  88500.2578125 81683.5859375
# epoch#0 batch#80 scenes#800  avg loss per scene(past 100):  60515.84375 56603.91796875
# epoch#0 batch#100 scenes#1000  avg loss per scene(past 100):  47431.265625 40524.05078125
# epoch#0 batch#120 scenes#1200  avg loss per scene(past 100):  47396.36328125 29581.623046875
# epoch#0 batch#140 scenes#1400  avg loss per scene(past 100):  42298.6953125 50429.24609375
# epoch#0 batch#160 scenes#1600  avg loss per scene(past 100):  37675.1328125 38992.7890625
# epoch#0 batch#180 scenes#1800  avg loss per scene(past 100):  30586.404296875 23041.03125
# epoch#0 batch#200 scenes#2000  avg loss per scene(past 100):  35121.0859375 43862.734375
# epoch#0 batch#220 scenes#2200  avg loss per scene(past 100):  28509.234375 44965.4765625
# epoch#0 batch#240 scenes#2400  avg loss per scene(past 100):  23799.806640625 22179.26171875
# epoch#0 batch#260 scenes#2600  avg loss per scene(past 100):  22919.27734375 31103.025390625
# epoch#0 batch#280 scenes#2800  avg loss per scene(past 100):  20137.162109375 12766.9267578125
# epoch#0 batch#300 scenes#3000  avg loss per scene(past 100):  21883.66015625 36975.1328125
# epoch#0 batch#320 scenes#3200  avg loss per scene(past 100):  19546.1484375 16501.416015625
# epoch#0 batch#340 scenes#3400  avg loss per scene(past 100):  19121.953125 21688.1875
# epoch#0 batch#360 scenes#3600  avg loss per scene(past 100):  19438.291015625 22408.322265625
# epoch#0 batch#380 scenes#3800  avg loss per scene(past 100):  18226.494140625 18822.369140625
# epoch#0 batch#400 scenes#4000  avg loss per scene(past 100):  16982.912109375 12742.4306640625
# epoch#0 batch#420 scenes#4200  avg loss per scene(past 100):  16760.73828125 17762.96484375
# epoch#0 batch#440 scenes#4400  avg loss per scene(past 100):  16479.55078125 15306.5634765625
# epoch#0 batch#460 scenes#4600  avg loss per scene(past 100):  15141.5888671875 12602.4892578125
# epoch#0 batch#480 scenes#4800  avg loss per scene(past 100):  14458.2392578125 10502.8994140625
# epoch#0 batch#500 scenes#5000  avg loss per scene(past 100):  13858.0009765625 11677.6640625
# epoch#0 batch#520 scenes#5200  avg loss per scene(past 100):  15035.00390625 12345.8818359375
# epoch#0 batch#540 scenes#5400  avg loss per scene(past 100):  14567.49609375 14195.8603515625
# epoch#0 batch#560 scenes#5600  avg loss per scene(past 100):  14217.5400390625 11316.513671875
# epoch#0 batch#580 scenes#5800  avg loss per scene(past 100):  14050.76171875 10964.5048828125
# epoch#0 batch#600 scenes#6000  avg loss per scene(past 100):  14290.2021484375 11958.169921875
# epoch#0 batch#620 scenes#6200  avg loss per scene(past 100):  13578.857421875 10207.015625
# epoch#0 batch#640 scenes#6400  avg loss per scene(past 100):  10451.4287109375 8833.6142578125
# epoch#0 batch#660 scenes#6600  avg loss per scene(past 100):  10368.0009765625 8764.7236328125
# epoch#0 batch#680 scenes#6800  avg loss per scene(past 100):  10840.4853515625 6557.4189453125
# epoch#0 batch#700 scenes#7000  avg loss per scene(past 100):  10384.4462890625 7453.5224609375
# epoch#0 batch#720 scenes#7200  avg loss per scene(past 100):  9783.109375 6992.24365234375
# epoch#0 batch#740 scenes#7400  avg loss per scene(past 100):  8383.3818359375 7635.201171875
# epoch#0 batch#760 scenes#7600  avg loss per scene(past 100):  8562.21484375 7657.89794921875
# epoch#0 batch#780 scenes#7800  avg loss per scene(past 100):  9568.2265625 8460.5869140625
# epoch#0 batch#800 scenes#8000  avg loss per scene(past 100):  9417.47265625 9932.4287109375
# epoch#0 batch#820 scenes#8200  avg loss per scene(past 100):  8748.587890625 6523.33984375
# epoch#0 batch#840 scenes#8400  avg loss per scene(past 100):  7859.91748046875 7308.5234375
# epoch#0 batch#860 scenes#8600  avg loss per scene(past 100):  8085.1376953125 6872.06298828125
# epoch#0 batch#880 scenes#8800  avg loss per scene(past 100):  9934.576171875 12329.806640625
# epoch#0 batch#900 scenes#9000  avg loss per scene(past 100):  8603.115234375 5406.978515625
# epoch#0 batch#920 scenes#9200  avg loss per scene(past 100):  10034.865234375 6248.98486328125
# epoch#0 batch#940 scenes#9400  avg loss per scene(past 100):  9727.6103515625 5088.8408203125
# epoch#0 batch#960 scenes#9600  avg loss per scene(past 100):  6705.58251953125 6832.98779296875
# epoch#0 batch#980 scenes#9800  avg loss per scene(past 100):  8297.8974609375 19999.462890625
# epoch#0 batch#1000 scenes#10000  avg loss per scene(past 100):  7528.7041015625 11260.28125
# epoch#0 batch#1020 scenes#10200  avg loss per scene(past 100):  6646.376953125 9335.0810546875
# epoch#0 batch#1040 scenes#10400  avg loss per scene(past 100):  6979.40771484375 13369.443359375
# epoch#0 batch#1060 scenes#10600  avg loss per scene(past 100):  6877.4912109375 5292.33349609375
# epoch#0 batch#1080 scenes#10800  avg loss per scene(past 100):  6260.9443359375 9443.1796875
# epoch#0 batch#1100 scenes#11000  avg loss per scene(past 100):  7331.92724609375 7618.21142578125
# epoch#0 batch#1120 scenes#11200  avg loss per scene(past 100):  6609.83154296875 7933.1220703125
# epoch#0 batch#1140 scenes#11400  avg loss per scene(past 100):  6763.51708984375 11144.888671875
# epoch#0 batch#1160 scenes#11600  avg loss per scene(past 100):  6551.53515625 9411.123046875
# epoch#0 batch#1180 scenes#11800  avg loss per scene(past 100):  5418.71484375 5025.16455078125
# epoch#0 batch#1200 scenes#12000  avg loss per scene(past 100):  5594.19384765625 7324.9951171875
# epoch#0 batch#1220 scenes#12200  avg loss per scene(past 100):  5763.6123046875 4003.142333984375
# epoch#0 batch#1240 scenes#12400  avg loss per scene(past 100):  5614.90380859375 11321.150390625
# epoch#0 batch#1260 scenes#12600  avg loss per scene(past 100):  5931.525390625 5581.5546875
# epoch#0 batch#1280 scenes#12800  avg loss per scene(past 100):  5696.7783203125 4063.575927734375
# epoch#0 batch#1300 scenes#13000  avg loss per scene(past 100):  5477.23388671875 3174.285888671875
# epoch#0 batch#1320 scenes#13200  avg loss per scene(past 100):  5331.625 3284.5361328125
# epoch#0 batch#1340 scenes#13400  avg loss per scene(past 100):  5291.052734375 4749.21435546875
# epoch#0 batch#1360 scenes#13600  avg loss per scene(past 100):  9210.8759765625 4538.572265625
# epoch#0 batch#1380 scenes#13800  avg loss per scene(past 100):  4991.19580078125 3027.996826171875
# epoch#0 batch#1400 scenes#14000  avg loss per scene(past 100):  4630.94287109375 3321.332275390625
# epoch#0 batch#1420 scenes#14200  avg loss per scene(past 100):  3779.4287109375 2461.578369140625
# epoch#0 batch#1440 scenes#14400  avg loss per scene(past 100):  5158.9423828125 3487.6640625
# epoch#0 batch#1460 scenes#14600  avg loss per scene(past 100):  5516.9462890625 10569.7236328125
# epoch#0 batch#1480 scenes#14800  avg loss per scene(past 100):  4023.30126953125 3813.219970703125
# epoch#0 batch#1500 scenes#15000  avg loss per scene(past 100):  4551.826171875 4528.96826171875
# epoch#0 batch#1520 scenes#15200  avg loss per scene(past 100):  4841.62890625 2775.666259765625
# epoch#0 batch#1540 scenes#15400  avg loss per scene(past 100):  5254.27099609375 6054.5244140625
# epoch#0 batch#1560 scenes#15600  avg loss per scene(past 100):  4981.74609375 16102.9228515625
# epoch#0 batch#1580 scenes#15800  avg loss per scene(past 100):  4460.04931640625 4418.447265625
# epoch#0 batch#1600 scenes#16000  avg loss per scene(past 100):  4363.9384765625 2734.276123046875
# epoch#0 batch#1620 scenes#16200  avg loss per scene(past 100):  4178.900390625 5152.248046875
# epoch#0 batch#1640 scenes#16400  avg loss per scene(past 100):  3640.291015625 4281.95947265625
# epoch#0 batch#1660 scenes#16600  avg loss per scene(past 100):  4547.447265625 1751.5206298828125
# epoch#0 batch#1680 scenes#16800  avg loss per scene(past 100):  4139.66845703125 1515.144287109375
# epoch#0 batch#1700 scenes#17000  avg loss per scene(past 100):  4864.31591796875 7934.330078125
# epoch#0 batch#1720 scenes#17200  avg loss per scene(past 100):  5433.97607421875 4919.0966796875
# epoch#0 batch#1740 scenes#17400  avg loss per scene(past 100):  3938.162353515625 7506.12255859375
# epoch#0 batch#1760 scenes#17600  avg loss per scene(past 100):  3462.19189453125 2329.532470703125
# epoch#0 batch#1780 scenes#17800  avg loss per scene(past 100):  3133.47802734375 4082.1328125
# epoch#0 batch#1800 scenes#18000  avg loss per scene(past 100):  2959.32666015625 1562.3887939453125
# epoch#0 batch#1820 scenes#18200  avg loss per scene(past 100):  2727.551025390625 2532.47607421875
# epoch#0 batch#1840 scenes#18400  avg loss per scene(past 100):  3635.408935546875 1662.75048828125
# epoch#0 batch#1860 scenes#18600  avg loss per scene(past 100):  3061.597412109375 2322.55908203125
# epoch#0 batch#1880 scenes#18800  avg loss per scene(past 100):  3480.697998046875 1758.5433349609375
# epoch#0 batch#1900 scenes#19000  avg loss per scene(past 100):  3072.523681640625 2035.44384765625
# epoch#0 batch#1920 scenes#19200  avg loss per scene(past 100):  3447.786865234375 1673.63232421875
# epoch#0 batch#1940 scenes#19400  avg loss per scene(past 100):  2727.772216796875 2603.896240234375
# epoch#0 batch#1960 scenes#19600  avg loss per scene(past 100):  2586.584228515625 2585.84619140625
# epoch#0 batch#1980 scenes#19800  avg loss per scene(past 100):  2806.988037109375 2759.3408203125
# epoch#0 batch#2000 scenes#20000  avg loss per scene(past 100):  2555.01220703125 2832.18408203125
# epoch#0 batch#2020 scenes#20200  avg loss per scene(past 100):  2382.249267578125 1810.6593017578125
# epoch#0 batch#2040 scenes#20400  avg loss per scene(past 100):  3377.837890625 2037.2451171875
# epoch#0 batch#2060 scenes#20600  avg loss per scene(past 100):  2617.920654296875 2530.664794921875
# epoch#0 batch#2080 scenes#20800  avg loss per scene(past 100):  2557.869384765625 3308.373046875
# epoch#0 batch#2100 scenes#21000  avg loss per scene(past 100):  2363.56005859375 3485.845458984375
# epoch#0 batch#2120 scenes#21200  avg loss per scene(past 100):  2839.88623046875 1358.56884765625
# epoch#0 batch#2140 scenes#21400  avg loss per scene(past 100):  2192.89794921875 4298.67724609375
# epoch#0 batch#2160 scenes#21600  avg loss per scene(past 100):  2358.47509765625 3486.86669921875
# epoch#0 batch#2180 scenes#21800  avg loss per scene(past 100):  2405.4482421875 1833.90087890625
# epoch#0 batch#2200 scenes#22000  avg loss per scene(past 100):  2718.20166015625 3827.583251953125
# epoch#0 batch#2220 scenes#22200  avg loss per scene(past 100):  3257.1220703125 5330.0341796875
# epoch#0 batch#2240 scenes#22400  avg loss per scene(past 100):  2614.084716796875 2868.736083984375
# epoch#0 batch#2260 scenes#22600  avg loss per scene(past 100):  2106.112548828125 1425.44677734375
# epoch#0 batch#2280 scenes#22800  avg loss per scene(past 100):  2269.178466796875 3588.3896484375
# epoch#0 batch#2300 scenes#23000  avg loss per scene(past 100):  1867.23779296875 3031.4560546875
# epoch#0 batch#2320 scenes#23200  avg loss per scene(past 100):  2486.089599609375 666.3234252929688
# epoch#0 batch#2340 scenes#23400  avg loss per scene(past 100):  2156.990478515625 2005.2166748046875
# epoch#0 batch#2360 scenes#23600  avg loss per scene(past 100):  2699.35400390625 701.5057373046875
# epoch#0 batch#2380 scenes#23800  avg loss per scene(past 100):  2814.781982421875 3446.12646484375
# epoch#0 batch#2400 scenes#24000  avg loss per scene(past 100):  2238.6015625 1881.666259765625
# epoch#0 batch#2420 scenes#24200  avg loss per scene(past 100):  1756.50927734375 952.185791015625
# epoch#0 batch#2440 scenes#24400  avg loss per scene(past 100):  1602.043212890625 612.6214599609375
# epoch#0 batch#2460 scenes#24600  avg loss per scene(past 100):  1903.087158203125 1364.3153076171875
# epoch#0 batch#2480 scenes#24800  avg loss per scene(past 100):  2384.46826171875 1109.0213623046875
# epoch#0 batch#2500 scenes#25000  avg loss per scene(past 100):  2768.927490234375 2036.646240234375
# epoch#0 batch#2520 scenes#25200  avg loss per scene(past 100):  1900.1787109375 1117.9033203125
# epoch#0 batch#2540 scenes#25400  avg loss per scene(past 100):  2298.02685546875 2064.5400390625
# epoch#0 batch#2560 scenes#25600  avg loss per scene(past 100):  2675.221923828125 1364.546630859375
# epoch#0 batch#2580 scenes#25800  avg loss per scene(past 100):  2622.01171875 927.546875
# epoch#0 batch#2600 scenes#26000  avg loss per scene(past 100):  1843.8271484375 1341.5338134765625
# epoch#0 batch#2620 scenes#26200  avg loss per scene(past 100):  2019.439208984375 4261.46728515625
# epoch#0 batch#2640 scenes#26400  avg loss per scene(past 100):  1469.37548828125 440.7851257324219
# epoch#0 batch#2660 scenes#26600  avg loss per scene(past 100):  2205.013916015625 2686.93798828125
# epoch#0 batch#2680 scenes#26800  avg loss per scene(past 100):  2261.90380859375 1945.6405029296875
# epoch#0 batch#2700 scenes#27000  avg loss per scene(past 100):  2147.995361328125 1922.3662109375
# epoch#0 batch#2720 scenes#27200  avg loss per scene(past 100):  1605.7110595703125 2290.399658203125
# epoch#0 batch#2740 scenes#27400  avg loss per scene(past 100):  1745.054931640625 1094.7093505859375
# epoch#0 batch#2760 scenes#27600  avg loss per scene(past 100):  1394.5313720703125 385.17071533203125
# epoch#0 batch#2780 scenes#27800  avg loss per scene(past 100):  1486.939697265625 897.03369140625
# epoch#0 batch#2800 scenes#28000  avg loss per scene(past 100):  1654.9710693359375 1311.869140625
# epoch#0 batch#2820 scenes#28200  avg loss per scene(past 100):  2402.988525390625 3189.141357421875
# epoch#0 batch#2840 scenes#28400  avg loss per scene(past 100):  2164.734375 1434.5400390625
# epoch#0 batch#2860 scenes#28600  avg loss per scene(past 100):  3307.76953125 1960.5858154296875
# epoch#0 batch#2880 scenes#28800  avg loss per scene(past 100):  1709.9405517578125 471.50445556640625
# epoch#0 batch#2900 scenes#29000  avg loss per scene(past 100):  1490.5616455078125 2441.198974609375
# epoch#0 batch#2920 scenes#29200  avg loss per scene(past 100):  1346.1273193359375 2376.240234375
# epoch#0 batch#2940 scenes#29400  avg loss per scene(past 100):  2176.399169921875 2121.3701171875
# epoch#0 batch#2960 scenes#29600  avg loss per scene(past 100):  1633.04150390625 1181.187744140625
# epoch#0 batch#2980 scenes#29800  avg loss per scene(past 100):  1331.2288818359375 1032.949951171875
# epoch#0 batch#3000 scenes#30000  avg loss per scene(past 100):  1794.959716796875 2454.880615234375
# epoch#0 batch#3020 scenes#30200  avg loss per scene(past 100):  1753.90625 3030.2958984375
# epoch#0 batch#3040 scenes#30400  avg loss per scene(past 100):  1688.2779541015625 858.6282348632812
# epoch#0 batch#3060 scenes#30600  avg loss per scene(past 100):  1882.9593505859375 2652.954833984375
# epoch#0 batch#3080 scenes#30800  avg loss per scene(past 100):  1613.00830078125 862.54736328125
# epoch#0 batch#3100 scenes#31000  avg loss per scene(past 100):  1108.1405029296875 297.4401550292969
# epoch#0 batch#3120 scenes#31200  avg loss per scene(past 100):  1511.098388671875 1399.2489013671875
# epoch#0 batch#3140 scenes#31400  avg loss per scene(past 100):  1486.596435546875 1851.7559814453125
# epoch#0 batch#3160 scenes#31600  avg loss per scene(past 100):  1461.82080078125 1511.009765625
# epoch#0 batch#3180 scenes#31800  avg loss per scene(past 100):  1640.9012451171875 887.3029174804688
# epoch#0 batch#3200 scenes#32000  avg loss per scene(past 100):  1424.5665283203125 923.10498046875
# epoch#0 batch#3220 scenes#32200  avg loss per scene(past 100):  1187.09716796875 318.7273864746094
# epoch#0 batch#3240 scenes#32400  avg loss per scene(past 100):  1441.4945068359375 1569.9207763671875
# epoch#0 batch#3260 scenes#32600  avg loss per scene(past 100):  1297.119384765625 2127.657958984375
# epoch#0 batch#3280 scenes#32800  avg loss per scene(past 100):  1286.7720947265625 745.6890258789062
# epoch#0 batch#3300 scenes#33000  avg loss per scene(past 100):  996.272216796875 670.3511352539062
# epoch#0 batch#3320 scenes#33200  avg loss per scene(past 100):  1291.129638671875 1216.87841796875
# epoch#0 batch#3340 scenes#33400  avg loss per scene(past 100):  1012.6500244140625 443.8476257324219
# epoch#0 batch#3360 scenes#33600  avg loss per scene(past 100):  1085.1458740234375 604.8433227539062
# epoch#0 batch#3380 scenes#33800  avg loss per scene(past 100):  1941.0010986328125 977.027099609375
# epoch#0 batch#3400 scenes#34000  avg loss per scene(past 100):  1664.960205078125 2117.7919921875
# epoch#0 batch#3420 scenes#34200  avg loss per scene(past 100):  1381.0311279296875 2121.402099609375
# epoch#0 batch#3440 scenes#34400  avg loss per scene(past 100):  983.0147094726562 659.2813720703125
# epoch#0 batch#3460 scenes#34600  avg loss per scene(past 100):  1244.8804931640625 623.2198486328125
# epoch#0 batch#3480 scenes#34800  avg loss per scene(past 100):  1160.815185546875 509.2760009765625
# epoch#0 batch#3500 scenes#35000  avg loss per scene(past 100):  1523.470703125 2336.001708984375
# epoch#0 batch#3520 scenes#35200  avg loss per scene(past 100):  2186.9951171875 819.8563232421875
# epoch#0 batch#3540 scenes#35400  avg loss per scene(past 100):  1076.76513671875 508.94610595703125
# epoch#0 batch#3560 scenes#35600  avg loss per scene(past 100):  1219.9793701171875 1849.2752685546875
# epoch#0 batch#3580 scenes#35800  avg loss per scene(past 100):  1170.9837646484375 417.55712890625
# epoch#0 batch#3600 scenes#36000  avg loss per scene(past 100):  1249.403076171875 433.3727722167969
# epoch#0 batch#3620 scenes#36200  avg loss per scene(past 100):  1149.3267822265625 2449.646728515625
# epoch#0 batch#3640 scenes#36400  avg loss per scene(past 100):  1236.1973876953125 1540.6357421875
# epoch#0 batch#3660 scenes#36600  avg loss per scene(past 100):  1079.3248291015625 1309.955322265625
# epoch#0 batch#3680 scenes#36800  avg loss per scene(past 100):  1513.233154296875 2440.438232421875
# epoch#0 batch#3700 scenes#37000  avg loss per scene(past 100):  868.1589965820312 611.4600219726562
# epoch#0 batch#3720 scenes#37200  avg loss per scene(past 100):  937.6765747070312 807.5737915039062
# epoch#0 batch#3740 scenes#37400  avg loss per scene(past 100):  1048.25390625 306.83306884765625
# epoch#0 batch#3760 scenes#37600  avg loss per scene(past 100):  1192.1939697265625 641.8275756835938
# epoch#0 batch#3780 scenes#37800  avg loss per scene(past 100):  1059.362548828125 1555.435791015625
# epoch#0 batch#3800 scenes#38000  avg loss per scene(past 100):  1064.97265625 686.4945678710938
# epoch#0 batch#3820 scenes#38200  avg loss per scene(past 100):  1097.6051025390625 347.3858337402344
# epoch#0 batch#3840 scenes#38400  avg loss per scene(past 100):  869.81787109375 345.8666687011719
# epoch#0 batch#3860 scenes#38600  avg loss per scene(past 100):  687.628173828125 325.1471862792969
# epoch#0 batch#3880 scenes#38800  avg loss per scene(past 100):  1033.041015625 924.9288330078125
# epoch#0 batch#3900 scenes#39000  avg loss per scene(past 100):  1183.7403564453125 2313.84716796875
# epoch#0 batch#3920 scenes#39200  avg loss per scene(past 100):  1915.229736328125 998.9844360351562
# epoch#0 batch#3940 scenes#39400  avg loss per scene(past 100):  1203.007568359375 1298.775390625
# epoch#0 batch#3960 scenes#39600  avg loss per scene(past 100):  938.4829711914062 1183.1044921875
# epoch#0 batch#3980 scenes#39800  avg loss per scene(past 100):  1114.5926513671875 468.03533935546875
# epoch#0 batch#4000 scenes#40000  avg loss per scene(past 100):  1037.0506591796875 616.1080932617188
# epoch#0 batch#4020 scenes#40200  avg loss per scene(past 100):  1042.1051025390625 681.0579223632812
# epoch#0 batch#4040 scenes#40400  avg loss per scene(past 100):  952.430419921875 3308.251708984375
# epoch#0 batch#4060 scenes#40600  avg loss per scene(past 100):  947.412353515625 609.2142944335938
# epoch#0 batch#4080 scenes#40800  avg loss per scene(past 100):  1455.1326904296875 630.7693481445312
# epoch#0 batch#4100 scenes#41000  avg loss per scene(past 100):  1134.56640625 1190.3157958984375
# epoch#0 batch#4120 scenes#41200  avg loss per scene(past 100):  1177.562255859375 1194.916259765625
# epoch#0 batch#4140 scenes#41400  avg loss per scene(past 100):  924.3709106445312 560.5248413085938
# epoch#0 batch#4160 scenes#41600  avg loss per scene(past 100):  1440.534912109375 2781.984130859375
# epoch#0 batch#4180 scenes#41800  avg loss per scene(past 100):  1442.1497802734375 645.09912109375
# epoch#0 batch#4200 scenes#42000  avg loss per scene(past 100):  1091.9959716796875 482.5702209472656
# epoch#0 batch#4220 scenes#42200  avg loss per scene(past 100):  810.8097534179688 289.6758117675781
# epoch#0 batch#4240 scenes#42400  avg loss per scene(past 100):  706.98828125 676.2454223632812
# epoch#0 batch#4260 scenes#42600  avg loss per scene(past 100):  536.344970703125 214.21620178222656
# epoch#0 batch#4280 scenes#42800  avg loss per scene(past 100):  661.0445556640625 492.7896728515625
# epoch#0 batch#4300 scenes#43000  avg loss per scene(past 100):  1137.183837890625 1465.638916015625
# epoch#0 batch#4320 scenes#43200  avg loss per scene(past 100):  799.0712890625 469.7157897949219
# epoch#0 batch#4340 scenes#43400  avg loss per scene(past 100):  878.81591796875 1050.361572265625
# epoch#0 batch#4360 scenes#43600  avg loss per scene(past 100):  862.2554321289062 398.9079284667969
# epoch#0 batch#4380 scenes#43800  avg loss per scene(past 100):  837.7637939453125 438.7461242675781
# epoch#0 batch#4400 scenes#44000  avg loss per scene(past 100):  845.9317016601562 455.5888366699219
# epoch#0 batch#4420 scenes#44200  avg loss per scene(past 100):  959.8147583007812 767.7994995117188
# epoch#0 batch#4440 scenes#44400  avg loss per scene(past 100):  1395.52001953125 1991.6689453125
# epoch#0 batch#4460 scenes#44600  avg loss per scene(past 100):  821.8358764648438 342.3383483886719
# epoch#0 batch#4480 scenes#44800  avg loss per scene(past 100):  576.0690307617188 234.75538635253906
# epoch#0 batch#4500 scenes#45000  avg loss per scene(past 100):  1205.301025390625 324.5028381347656
# epoch#0 batch#4520 scenes#45200  avg loss per scene(past 100):  904.5748291015625 725.6461181640625
# epoch#0 batch#4540 scenes#45400  avg loss per scene(past 100):  629.1517944335938 569.2274780273438
# epoch#0 batch#4560 scenes#45600  avg loss per scene(past 100):  692.227294921875 1560.7626953125
# epoch#0 batch#4580 scenes#45800  avg loss per scene(past 100):  801.4682006835938 636.8734130859375
# epoch#0 batch#4600 scenes#46000  avg loss per scene(past 100):  674.547607421875 198.38978576660156
# epoch#0 batch#4620 scenes#46200  avg loss per scene(past 100):  728.8438720703125 991.9202270507812
# epoch#0 batch#4640 scenes#46400  avg loss per scene(past 100):  863.148681640625 169.81283569335938
# epoch#0 batch#4660 scenes#46600  avg loss per scene(past 100):  1000.7008666992188 758.439697265625
# epoch#0 batch#4680 scenes#46800  avg loss per scene(past 100):  958.0758056640625 2806.33154296875
# epoch#0 batch#4700 scenes#47000  avg loss per scene(past 100):  845.861328125 732.9513549804688
# epoch#0 batch#4720 scenes#47200  avg loss per scene(past 100):  768.5922241210938 273.6468200683594
# epoch#0 batch#4740 scenes#47400  avg loss per scene(past 100):  784.8170166015625 551.0538940429688
# epoch#0 batch#4760 scenes#47600  avg loss per scene(past 100):  1268.205078125 1514.3680419921875
# epoch#0 batch#4780 scenes#47800  avg loss per scene(past 100):  759.2478637695312 639.3076171875
# epoch#0 batch#4800 scenes#48000  avg loss per scene(past 100):  1053.0084228515625 1419.9119873046875
# epoch#0 batch#4820 scenes#48200  avg loss per scene(past 100):  1083.01806640625 391.1797180175781
# epoch#0 batch#4840 scenes#48400  avg loss per scene(past 100):  729.4537353515625 1301.0560302734375
# epoch#0 batch#4860 scenes#48600  avg loss per scene(past 100):  884.8726806640625 254.1543426513672
# epoch#0 batch#4880 scenes#48800  avg loss per scene(past 100):  1155.1617431640625 1605.541748046875
# epoch#0 batch#4900 scenes#49000  avg loss per scene(past 100):  755.1473388671875 733.2811279296875
# epoch#0 batch#4920 scenes#49200  avg loss per scene(past 100):  963.2205200195312 1160.1019287109375
# epoch#0 batch#4940 scenes#49400  avg loss per scene(past 100):  1126.836181640625 1039.858154296875
# epoch#0 batch#4960 scenes#49600  avg loss per scene(past 100):  981.6129760742188 382.310791015625
# epoch#0 batch#4980 scenes#49800  avg loss per scene(past 100):  648.03369140625 321.5639343261719
# epoch#0 batch#5000 scenes#50000  avg loss per scene(past 100):  532.3060302734375 539.7200317382812
# epoch#0 batch#5020 scenes#50200  avg loss per scene(past 100):  670.1204223632812 470.32232666015625
# epoch#0 batch#5040 scenes#50400  avg loss per scene(past 100):  1064.728271484375 540.9627685546875
# epoch#0 batch#5060 scenes#50600  avg loss per scene(past 100):  987.3264770507812 243.5287322998047
# epoch#0 batch#5080 scenes#50800  avg loss per scene(past 100):  969.2888793945312 631.1041870117188
# epoch#0 batch#5100 scenes#51000  avg loss per scene(past 100):  705.234130859375 837.1282958984375
# epoch#0 batch#5120 scenes#51200  avg loss per scene(past 100):  1440.3067626953125 1041.02490234375
# epoch#0 batch#5140 scenes#51400  avg loss per scene(past 100):  875.6458740234375 554.9942016601562
# epoch#0 batch#5160 scenes#51600  avg loss per scene(past 100):  878.2565307617188 2318.318603515625
# epoch#0 batch#5180 scenes#51800  avg loss per scene(past 100):  977.2085571289062 227.0517578125
# epoch#0 batch#5200 scenes#52000  avg loss per scene(past 100):  1141.7720947265625 315.6935729980469
# epoch#0 batch#5220 scenes#52200  avg loss per scene(past 100):  578.8165283203125 245.27000427246094
# epoch#0 batch#5240 scenes#52400  avg loss per scene(past 100):  638.941162109375 628.5588989257812
# epoch#0 batch#5260 scenes#52600  avg loss per scene(past 100):  601.4143676757812 312.620849609375
# epoch#0 batch#5280 scenes#52800  avg loss per scene(past 100):  838.3646240234375 973.40625
# epoch#0 batch#5300 scenes#53000  avg loss per scene(past 100):  902.3125610351562 580.3734741210938
# epoch#0 batch#5320 scenes#53200  avg loss per scene(past 100):  571.78955078125 383.1932067871094
# epoch#0 batch#5340 scenes#53400  avg loss per scene(past 100):  1032.774658203125 306.0069580078125
# epoch#0 batch#5360 scenes#53600  avg loss per scene(past 100):  568.944580078125 146.9944610595703
# epoch#0 batch#5380 scenes#53800  avg loss per scene(past 100):  688.7583618164062 368.5913391113281
# epoch#0 batch#5400 scenes#54000  avg loss per scene(past 100):  1091.46875 219.570556640625
# epoch#0 batch#5420 scenes#54200  avg loss per scene(past 100):  835.4751586914062 382.412841796875
# epoch#0 batch#5440 scenes#54400  avg loss per scene(past 100):  887.6258544921875 1532.4599609375
# epoch#0 batch#5460 scenes#54600  avg loss per scene(past 100):  474.30615234375 188.88978576660156
# epoch#0 batch#5480 scenes#54800  avg loss per scene(past 100):  946.1516723632812 170.8494415283203
# epoch#0 batch#5500 scenes#55000  avg loss per scene(past 100):  614.7994384765625 519.0220336914062
# epoch#0 batch#5520 scenes#55200  avg loss per scene(past 100):  444.9607238769531 291.5615539550781
# epoch#0 batch#5540 scenes#55400  avg loss per scene(past 100):  550.1802368164062 608.5245971679688
# epoch#0 batch#5560 scenes#55600  avg loss per scene(past 100):  514.2119140625 259.24737548828125
# epoch#0 batch#5580 scenes#55800  avg loss per scene(past 100):  548.9224853515625 154.81777954101562
# epoch#0 batch#5600 scenes#56000  avg loss per scene(past 100):  1005.8715209960938 580.826416015625
# epoch#0 batch#5620 scenes#56200  avg loss per scene(past 100):  583.9246826171875 1189.7335205078125
# epoch#0 batch#5640 scenes#56400  avg loss per scene(past 100):  750.0861206054688 208.28176879882812
# epoch#0 batch#5660 scenes#56600  avg loss per scene(past 100):  877.9854125976562 2124.703125
# epoch#0 batch#5680 scenes#56800  avg loss per scene(past 100):  917.8885498046875 731.4006958007812
# epoch#0 batch#5700 scenes#57000  avg loss per scene(past 100):  583.83984375 175.68638610839844
# epoch#0 batch#5720 scenes#57200  avg loss per scene(past 100):  547.6342163085938 361.66461181640625
# epoch#0 batch#5740 scenes#57400  avg loss per scene(past 100):  1104.044677734375 2666.640380859375
# epoch#0 batch#5760 scenes#57600  avg loss per scene(past 100):  708.6796875 794.7863159179688
# epoch#0 batch#5780 scenes#57800  avg loss per scene(past 100):  622.4182739257812 958.6082153320312
# epoch#0 batch#5800 scenes#58000  avg loss per scene(past 100):  1115.3436279296875 220.87646484375
# epoch#0 batch#5820 scenes#58200  avg loss per scene(past 100):  596.997802734375 165.1741943359375
# epoch#0 batch#5840 scenes#58400  avg loss per scene(past 100):  448.03839111328125 203.22975158691406
# epoch#0 batch#5860 scenes#58600  avg loss per scene(past 100):  973.8673095703125 483.8157958984375
# epoch#0 batch#5880 scenes#58800  avg loss per scene(past 100):  556.966796875 284.44061279296875
# epoch#0 batch#5900 scenes#59000  avg loss per scene(past 100):  451.25933837890625 316.71337890625
# epoch#0 batch#5920 scenes#59200  avg loss per scene(past 100):  477.99713134765625 456.6058044433594
# epoch#0 batch#5940 scenes#59400  avg loss per scene(past 100):  466.0196533203125 456.6662292480469
# epoch#0 batch#5960 scenes#59600  avg loss per scene(past 100):  437.7814025878906 321.1705627441406
# epoch#0 batch#5980 scenes#59800  avg loss per scene(past 100):  291.0456237792969 135.77024841308594
# epoch#0 batch#6000 scenes#60000  avg loss per scene(past 100):  659.6290283203125 569.0499877929688
# epoch#0 batch#6020 scenes#60200  avg loss per scene(past 100):  482.7496337890625 245.5848388671875
# epoch#0 batch#6040 scenes#60400  avg loss per scene(past 100):  661.2725219726562 905.6499633789062
# epoch#0 batch#6060 scenes#60600  avg loss per scene(past 100):  414.53973388671875 131.96932983398438
# epoch#0 batch#6080 scenes#60800  avg loss per scene(past 100):  1361.23681640625 257.59814453125
# epoch#0 batch#6100 scenes#61000  avg loss per scene(past 100):  984.962646484375 336.2201232910156
# epoch#0 batch#6120 scenes#61200  avg loss per scene(past 100):  836.5916748046875 903.2361450195312
# epoch#0 batch#6140 scenes#61400  avg loss per scene(past 100):  481.3748779296875 322.06787109375
# epoch#0 batch#6160 scenes#61600  avg loss per scene(past 100):  475.8161315917969 340.99749755859375
# epoch#0 batch#6180 scenes#61800  avg loss per scene(past 100):  313.3711242675781 238.01821899414062
# epoch#0 batch#6200 scenes#62000  avg loss per scene(past 100):  483.8048095703125 383.4571228027344
# epoch#0 batch#6220 scenes#62200  avg loss per scene(past 100):  773.79931640625 376.3572692871094
# epoch#0 batch#6240 scenes#62400  avg loss per scene(past 100):  384.1684265136719 142.67686462402344
# epoch#0 batch#6260 scenes#62600  avg loss per scene(past 100):  464.8218994140625 375.4076232910156
# epoch#0 batch#6280 scenes#62800  avg loss per scene(past 100):  483.4528503417969 157.3169403076172
# epoch#0 batch#6300 scenes#63000  avg loss per scene(past 100):  637.9982299804688 445.7397155761719
# epoch#0 batch#6320 scenes#63200  avg loss per scene(past 100):  523.3642578125 235.3514404296875
# epoch#0 batch#6340 scenes#63400  avg loss per scene(past 100):  506.24432373046875 92.39452362060547
# epoch#0 batch#6360 scenes#63600  avg loss per scene(past 100):  543.5169067382812 811.177001953125
# epoch#0 batch#6380 scenes#63800  avg loss per scene(past 100):  638.64453125 529.8485107421875
# epoch#0 batch#6400 scenes#64000  avg loss per scene(past 100):  458.27960205078125 333.239013671875
# epoch#0 batch#6420 scenes#64200  avg loss per scene(past 100):  429.39990234375 582.309814453125
# epoch#0 batch#6440 scenes#64400  avg loss per scene(past 100):  469.0936584472656 550.9336547851562
# epoch#0 batch#6460 scenes#64600  avg loss per scene(past 100):  433.64312744140625 193.03158569335938
# epoch#0 batch#6480 scenes#64800  avg loss per scene(past 100):  377.87286376953125 346.7775573730469
# epoch#0 batch#6500 scenes#65000  avg loss per scene(past 100):  613.1986694335938 2055.847900390625
# epoch#0 batch#6520 scenes#65200  avg loss per scene(past 100):  365.3167724609375 302.2493896484375
# epoch#0 batch#6540 scenes#65400  avg loss per scene(past 100):  293.0600891113281 142.01698303222656
# epoch#0 batch#6560 scenes#65600  avg loss per scene(past 100):  399.29400634765625 462.87261962890625
# epoch#0 batch#6580 scenes#65800  avg loss per scene(past 100):  800.1710205078125 324.523681640625
# epoch#0 batch#6600 scenes#66000  avg loss per scene(past 100):  337.36138916015625 137.1309356689453
# epoch#0 batch#6620 scenes#66200  avg loss per scene(past 100):  455.6373291015625 128.49942016601562
# epoch#0 batch#6640 scenes#66400  avg loss per scene(past 100):  265.7236328125 127.09044647216797
# epoch#0 batch#6660 scenes#66600  avg loss per scene(past 100):  701.6134643554688 228.49209594726562
# epoch#0 batch#6680 scenes#66800  avg loss per scene(past 100):  546.79296875 416.0815124511719
# epoch#0 batch#6700 scenes#67000  avg loss per scene(past 100):  575.975830078125 131.70367431640625
# epoch#0 batch#6720 scenes#67200  avg loss per scene(past 100):  362.77264404296875 139.5933074951172
# epoch#0 batch#6740 scenes#67400  avg loss per scene(past 100):  547.8971557617188 586.0022583007812
# epoch#0 batch#6760 scenes#67600  avg loss per scene(past 100):  500.23309326171875 220.83294677734375
# epoch#0 batch#6780 scenes#67800  avg loss per scene(past 100):  354.785888671875 223.70767211914062
# epoch#0 batch#6800 scenes#68000  avg loss per scene(past 100):  458.61895751953125 116.99038696289062
# epoch#0 batch#6820 scenes#68200  avg loss per scene(past 100):  705.9547729492188 1195.91259765625
# epoch#0 batch#6840 scenes#68400  avg loss per scene(past 100):  542.5673217773438 112.22792053222656
# epoch#0 batch#6860 scenes#68600  avg loss per scene(past 100):  955.93896484375 1285.9114990234375
# epoch#0 batch#6880 scenes#68800  avg loss per scene(past 100):  542.2310791015625 1454.50244140625
# epoch#0 batch#6900 scenes#69000  avg loss per scene(past 100):  452.43133544921875 154.3436737060547
# epoch#0 batch#6920 scenes#69200  avg loss per scene(past 100):  381.10406494140625 262.9808654785156
# epoch#0 batch#6940 scenes#69400  avg loss per scene(past 100):  615.838134765625 221.38003540039062
# epoch#0 batch#6960 scenes#69600  avg loss per scene(past 100):  384.7567138671875 1062.6624755859375
# epoch#0 batch#6980 scenes#69800  avg loss per scene(past 100):  408.0648193359375 917.6314697265625
# epoch#0 batch#7000 scenes#70000  avg loss per scene(past 100):  421.8429870605469 243.69747924804688
# epoch#0 batch#7020 scenes#70200  avg loss per scene(past 100):  603.30859375 256.6599426269531
# epoch#0 batch#7040 scenes#70400  avg loss per scene(past 100):  878.0484008789062 120.4626693725586
# epoch#0 batch#7060 scenes#70600  avg loss per scene(past 100):  680.802734375 340.3647766113281
# epoch#0 batch#7080 scenes#70800  avg loss per scene(past 100):  442.67535400390625 109.65751647949219
# epoch#0 batch#7100 scenes#71000  avg loss per scene(past 100):  605.1172485351562 998.1742553710938
# epoch#0 batch#7120 scenes#71200  avg loss per scene(past 100):  430.1548156738281 61.699790954589844
# epoch#0 batch#7140 scenes#71400  avg loss per scene(past 100):  358.1083984375 135.39186096191406
# epoch#0 batch#7160 scenes#71600  avg loss per scene(past 100):  494.885498046875 1043.9935302734375
# epoch#0 batch#7180 scenes#71800  avg loss per scene(past 100):  679.2398681640625 173.65200805664062
# epoch#0 batch#7200 scenes#72000  avg loss per scene(past 100):  529.3103637695312 143.34817504882812
# epoch#0 batch#7220 scenes#72200  avg loss per scene(past 100):  422.0591735839844 246.02549743652344
# epoch#0 batch#7240 scenes#72400  avg loss per scene(past 100):  372.9122009277344 836.9676513671875
# epoch#0 batch#7260 scenes#72600  avg loss per scene(past 100):  1432.42041015625 5375.60009765625
# epoch#0 batch#7280 scenes#72800  avg loss per scene(past 100):  620.12841796875 318.3514404296875
# epoch#0 batch#7300 scenes#73000  avg loss per scene(past 100):  456.0567321777344 137.94912719726562
# epoch#0 batch#7320 scenes#73200  avg loss per scene(past 100):  627.7440185546875 260.7579345703125
# epoch#0 batch#7340 scenes#73400  avg loss per scene(past 100):  436.18792724609375 175.68089294433594
# epoch#0 batch#7360 scenes#73600  avg loss per scene(past 100):  208.3596954345703 202.52407836914062
# epoch#0 batch#7380 scenes#73800  avg loss per scene(past 100):  462.65338134765625 305.3033447265625
# epoch#0 batch#7400 scenes#74000  avg loss per scene(past 100):  373.6328430175781 95.69049835205078
# epoch#0 batch#7420 scenes#74200  avg loss per scene(past 100):  375.6593933105469 119.3405990600586
# epoch#0 batch#7440 scenes#74400  avg loss per scene(past 100):  565.4578247070312 160.98126220703125
# epoch#0 batch#7460 scenes#74600  avg loss per scene(past 100):  437.9582214355469 331.4133605957031
# epoch#0 batch#7480 scenes#74800  avg loss per scene(past 100):  426.6693115234375 343.0406799316406
# epoch#0 batch#7500 scenes#75000  avg loss per scene(past 100):  236.5074462890625 122.68888854980469
# epoch#0 batch#7520 scenes#75200  avg loss per scene(past 100):  413.7041320800781 320.98944091796875
# epoch#0 batch#7540 scenes#75400  avg loss per scene(past 100):  489.10504150390625 144.13172912597656
# epoch#0 batch#7560 scenes#75600  avg loss per scene(past 100):  584.8276977539062 1126.48486328125
# epoch#0 batch#7580 scenes#75800  avg loss per scene(past 100):  353.5819091796875 128.8248291015625
# epoch#0 batch#7600 scenes#76000  avg loss per scene(past 100):  270.8747253417969 178.70425415039062
# epoch#0 batch#7620 scenes#76200  avg loss per scene(past 100):  409.19439697265625 261.5452575683594
# epoch#0 batch#7640 scenes#76400  avg loss per scene(past 100):  421.4679260253906 331.20513916015625
# epoch#0 batch#7660 scenes#76600  avg loss per scene(past 100):  536.4068603515625 571.6865844726562
# epoch#0 batch#7680 scenes#76800  avg loss per scene(past 100):  295.1558532714844 172.4618377685547
# epoch#0 batch#7700 scenes#77000  avg loss per scene(past 100):  203.1735076904297 89.27379608154297
# epoch#0 batch#7720 scenes#77200  avg loss per scene(past 100):  572.8650512695312 1043.430908203125
# epoch#0 batch#7740 scenes#77400  avg loss per scene(past 100):  377.1696472167969 251.00608825683594
# epoch#0 batch#7760 scenes#77600  avg loss per scene(past 100):  481.9789123535156 218.7010040283203
# epoch#0 batch#7780 scenes#77800  avg loss per scene(past 100):  398.0426025390625 445.375732421875
# epoch#0 batch#7800 scenes#78000  avg loss per scene(past 100):  920.912841796875 217.34262084960938
# epoch#0 batch#7820 scenes#78200  avg loss per scene(past 100):  1138.4571533203125 855.316650390625
# epoch#0 batch#7840 scenes#78400  avg loss per scene(past 100):  1046.461669921875 334.2427062988281
# epoch#0 batch#7860 scenes#78600  avg loss per scene(past 100):  587.1792602539062 122.22077941894531
# epoch#0 batch#7880 scenes#78800  avg loss per scene(past 100):  494.9908447265625 261.72698974609375
# epoch#0 batch#7900 scenes#79000  avg loss per scene(past 100):  317.6425476074219 79.179931640625
# epoch#0 batch#7920 scenes#79200  avg loss per scene(past 100):  246.49017333984375 303.45428466796875
# epoch#0 batch#7940 scenes#79400  avg loss per scene(past 100):  636.5902709960938 820.7840576171875
# epoch#0 batch#7960 scenes#79600  avg loss per scene(past 100):  501.7577209472656 115.48418426513672
# epoch#0 batch#7980 scenes#79800  avg loss per scene(past 100):  1110.8082275390625 414.3232116699219
# epoch#0 batch#8000 scenes#80000  avg loss per scene(past 100):  448.6960754394531 120.7215576171875
# epoch#0 batch#8020 scenes#80200  avg loss per scene(past 100):  382.2308044433594 152.9140167236328
# epoch#0 batch#8040 scenes#80400  avg loss per scene(past 100):  690.268310546875 3045.869873046875
# epoch#0 batch#8060 scenes#80600  avg loss per scene(past 100):  432.6104431152344 253.6387481689453
# epoch#0 batch#8080 scenes#80800  avg loss per scene(past 100):  378.2043762207031 1057.770751953125
# epoch#0 batch#8100 scenes#81000  avg loss per scene(past 100):  240.2194366455078 93.86552429199219
# epoch#0 batch#8120 scenes#81200  avg loss per scene(past 100):  271.7098388671875 123.90914154052734
# epoch#0 batch#8140 scenes#81400  avg loss per scene(past 100):  342.3409423828125 137.75477600097656
# epoch#0 batch#8160 scenes#81600  avg loss per scene(past 100):  404.86004638671875 257.9531555175781
# epoch#0 batch#8180 scenes#81800  avg loss per scene(past 100):  868.78759765625 4142.072265625
# epoch#0 batch#8200 scenes#82000  avg loss per scene(past 100):  764.66455078125 177.94749450683594
# epoch#0 batch#8220 scenes#82200  avg loss per scene(past 100):  344.30523681640625 281.78216552734375
# epoch#0 batch#8240 scenes#82400  avg loss per scene(past 100):  208.84402465820312 99.82319641113281
# epoch#0 batch#8260 scenes#82600  avg loss per scene(past 100):  356.96771240234375 934.1096801757812
# epoch#0 batch#8280 scenes#82800  avg loss per scene(past 100):  344.3555908203125 312.414794921875
# epoch#0 batch#8300 scenes#83000  avg loss per scene(past 100):  446.345703125 2362.36669921875
# epoch#0 batch#8320 scenes#83200  avg loss per scene(past 100):  275.4825439453125 337.9225158691406
# epoch#0 batch#8340 scenes#83400  avg loss per scene(past 100):  439.49212646484375 315.5498962402344
# epoch#0 batch#8360 scenes#83600  avg loss per scene(past 100):  538.74853515625 3400.701904296875
# epoch#0 batch#8380 scenes#83800  avg loss per scene(past 100):  422.8091125488281 113.03434753417969
# epoch#0 batch#8400 scenes#84000  avg loss per scene(past 100):  350.0228271484375 139.5830078125
# epoch#0 batch#8420 scenes#84200  avg loss per scene(past 100):  389.1553039550781 151.33641052246094
# epoch#0 batch#8440 scenes#84400  avg loss per scene(past 100):  212.9105987548828 76.44017791748047
# epoch#0 batch#8460 scenes#84600  avg loss per scene(past 100):  273.03472900390625 147.91563415527344
# epoch#0 batch#8480 scenes#84800  avg loss per scene(past 100):  313.828369140625 114.59235382080078
# epoch#0 batch#8500 scenes#85000  avg loss per scene(past 100):  262.012451171875 107.12844848632812
# epoch#0 batch#8520 scenes#85200  avg loss per scene(past 100):  324.357177734375 178.06736755371094
# epoch#0 batch#8540 scenes#85400  avg loss per scene(past 100):  223.73550415039062 86.33541870117188
# epoch#0 batch#8560 scenes#85600  avg loss per scene(past 100):  319.9376220703125 1118.0010986328125
# epoch#0 batch#8580 scenes#85800  avg loss per scene(past 100):  838.134765625 5056.39453125
# epoch#0 batch#8600 scenes#86000  avg loss per scene(past 100):  307.7986755371094 150.33155822753906
# epoch#0 batch#8620 scenes#86200  avg loss per scene(past 100):  285.43670654296875 927.9188842773438
# epoch#0 batch#8640 scenes#86400  avg loss per scene(past 100):  320.81085205078125 133.49591064453125
# epoch#0 batch#8660 scenes#86600  avg loss per scene(past 100):  319.78619384765625 317.1490173339844
# epoch#0 batch#8680 scenes#86800  avg loss per scene(past 100):  326.7946472167969 223.06349182128906
# epoch#0 batch#8700 scenes#87000  avg loss per scene(past 100):  310.8499755859375 248.7266082763672
# epoch#0 batch#8720 scenes#87200  avg loss per scene(past 100):  290.3897705078125 328.3668518066406
# epoch#0 batch#8740 scenes#87400  avg loss per scene(past 100):  276.0689392089844 343.88751220703125
# epoch#0 batch#8760 scenes#87600  avg loss per scene(past 100):  264.45037841796875 78.98960876464844
# epoch#0 batch#8780 scenes#87800  avg loss per scene(past 100):  206.84751892089844 133.07162475585938
# epoch#0 batch#8800 scenes#88000  avg loss per scene(past 100):  442.2303466796875 2635.97998046875
# epoch#0 batch#8820 scenes#88200  avg loss per scene(past 100):  300.52490234375 852.494873046875
# epoch#0 batch#8840 scenes#88400  avg loss per scene(past 100):  361.3701477050781 150.7606201171875
# epoch#0 batch#8860 scenes#88600  avg loss per scene(past 100):  627.3453369140625 166.90174865722656
# epoch#0 batch#8880 scenes#88800  avg loss per scene(past 100):  275.47430419921875 104.76640319824219
# epoch#0 batch#8900 scenes#89000  avg loss per scene(past 100):  424.28314208984375 1116.3819580078125
# epoch#0 batch#8920 scenes#89200  avg loss per scene(past 100):  241.2704620361328 164.68759155273438
# epoch#0 batch#8940 scenes#89400  avg loss per scene(past 100):  225.74436950683594 110.08316040039062
# epoch#0 batch#8960 scenes#89600  avg loss per scene(past 100):  328.6469421386719 679.6240234375
# epoch#0 batch#8980 scenes#89800  avg loss per scene(past 100):  228.45907592773438 98.58722686767578
# epoch#0 batch#9000 scenes#90000  avg loss per scene(past 100):  329.66021728515625 139.2418212890625
# epoch#0 batch#9020 scenes#90200  avg loss per scene(past 100):  442.91949462890625 428.80938720703125
# epoch#0 batch#9040 scenes#90400  avg loss per scene(past 100):  480.1998596191406 171.1209259033203
# epoch#0 batch#9060 scenes#90600  avg loss per scene(past 100):  428.3306579589844 118.78958129882812
# epoch#0 batch#9080 scenes#90800  avg loss per scene(past 100):  272.9847412109375 84.17896270751953
# epoch#0 batch#9100 scenes#91000  avg loss per scene(past 100):  481.710693359375 127.4599838256836
# epoch#0 batch#9120 scenes#91200  avg loss per scene(past 100):  424.7001037597656 198.4977569580078
# epoch#0 batch#9140 scenes#91400  avg loss per scene(past 100):  913.3876953125 213.43736267089844
# epoch#0 batch#9160 scenes#91600  avg loss per scene(past 100):  420.4983825683594 115.92078399658203
# epoch#0 batch#9180 scenes#91800  avg loss per scene(past 100):  332.3529052734375 343.2875061035156
# epoch#0 batch#9200 scenes#92000  avg loss per scene(past 100):  590.2432861328125 162.49082946777344
# epoch#0 batch#9220 scenes#92200  avg loss per scene(past 100):  467.619873046875 166.7777557373047
# epoch#0 batch#9240 scenes#92400  avg loss per scene(past 100):  486.77178955078125 89.01681518554688
# epoch#0 batch#9260 scenes#92600  avg loss per scene(past 100):  408.4566345214844 1505.570068359375
# epoch#0 batch#9280 scenes#92800  avg loss per scene(past 100):  184.64414978027344 75.46702575683594
# epoch#0 batch#9300 scenes#93000  avg loss per scene(past 100):  171.735595703125 81.42433166503906
# epoch#0 batch#9320 scenes#93200  avg loss per scene(past 100):  422.15386962890625 149.8402862548828
# epoch#0 batch#9340 scenes#93400  avg loss per scene(past 100):  341.14532470703125 101.30567932128906
# epoch#0 batch#9360 scenes#93600  avg loss per scene(past 100):  440.24285888671875 1215.576904296875
# epoch#0 batch#9380 scenes#93800  avg loss per scene(past 100):  335.007080078125 248.02322387695312
# epoch#0 batch#9400 scenes#94000  avg loss per scene(past 100):  229.93275451660156 121.43338775634766
# epoch#0 batch#9420 scenes#94200  avg loss per scene(past 100):  403.174560546875 1104.864501953125
# epoch#0 batch#9440 scenes#94400  avg loss per scene(past 100):  404.98876953125 880.6781005859375
# epoch#0 batch#9460 scenes#94600  avg loss per scene(past 100):  321.621337890625 103.66419982910156
# epoch#0 batch#9480 scenes#94800  avg loss per scene(past 100):  214.9608917236328 95.16545867919922
# epoch#0 batch#9500 scenes#95000  avg loss per scene(past 100):  195.90232849121094 80.11415100097656
# epoch#0 batch#9520 scenes#95200  avg loss per scene(past 100):  229.95278930664062 142.47764587402344
# epoch#0 batch#9540 scenes#95400  avg loss per scene(past 100):  126.70098876953125 61.37380599975586
# epoch#0 batch#9560 scenes#95600  avg loss per scene(past 100):  280.02825927734375 170.61216735839844
# epoch#0 batch#9580 scenes#95800  avg loss per scene(past 100):  767.2109375 260.1274719238281
# epoch#0 batch#9600 scenes#96000  avg loss per scene(past 100):  392.4532165527344 375.7413330078125
# epoch#0 batch#9620 scenes#96200  avg loss per scene(past 100):  391.8438415527344 103.55107116699219
# epoch#0 batch#9640 scenes#96400  avg loss per scene(past 100):  407.4056396484375 734.4822387695312
# epoch#0 batch#9660 scenes#96600  avg loss per scene(past 100):  250.01657104492188 89.5881118774414
# epoch#0 batch#9680 scenes#96800  avg loss per scene(past 100):  252.65512084960938 262.8962707519531
# epoch#0 batch#9700 scenes#97000  avg loss per scene(past 100):  384.3301086425781 761.8916625976562
# ...
# epoch#0 batch#17900 scenes#179000  avg loss per scene(past 100):  144.0852508544922 57.31948471069336
# epoch#0 batch#17920 scenes#179200  avg loss per scene(past 100):  223.36407470703125 57.97660827636719
# epoch#0 batch#17940 scenes#179400  avg loss per scene(past 100):  118.80980682373047 55.86981964111328
# epoch#0 batch#17960 scenes#179600  avg loss per scene(past 100):  87.7626953125 38.44008255004883
# epoch#0 batch#17980 scenes#179800  avg loss per scene(past 100):  193.2474822998047 78.38593292236328
# epoch#0 batch#18000 scenes#180000  avg loss per scene(past 100):  140.51747131347656 72.27643585205078
# epoch#0 batch#18020 scenes#180200  avg loss per scene(past 100):  149.1686248779297 59.007728576660156
# epoch#0 batch#18040 scenes#180400  avg loss per scene(past 100):  95.30555725097656 233.98817443847656
# epoch#0 batch#18060 scenes#180600  avg loss per scene(past 100):  116.20993041992188 52.58225631713867
# epoch#0 batch#18080 scenes#180800  avg loss per scene(past 100):  351.6915588378906 413.6252746582031
# epoch#0 batch#18100 scenes#181000  avg loss per scene(past 100):  211.22923278808594 56.568912506103516
# epoch#0 batch#18120 scenes#181200  avg loss per scene(past 100):  79.5420913696289 53.42406463623047
# epoch#0 batch#18140 scenes#181400  avg loss per scene(past 100):  109.4108657836914 72.96163177490234
# epoch#0 batch#18160 scenes#181600  avg loss per scene(past 100):  177.42056274414062 67.44419860839844
# epoch#0 batch#18180 scenes#181800  avg loss per scene(past 100):  98.62753295898438 135.82203674316406
# epoch#0 batch#18200 scenes#182000  avg loss per scene(past 100):  221.4917449951172 69.21240997314453
# epoch#0 batch#18220 scenes#182200  avg loss per scene(past 100):  199.473388671875 161.01441955566406
# epoch#0 batch#18240 scenes#182400  avg loss per scene(past 100):  151.06040954589844 61.40392303466797
# epoch#0 batch#18260 scenes#182600  avg loss per scene(past 100):  356.5281066894531 219.31179809570312
# epoch#0 batch#18280 scenes#182800  avg loss per scene(past 100):  301.53155517578125 970.748779296875
# epoch#0 batch#18300 scenes#183000  avg loss per scene(past 100):  351.78765869140625 117.29721069335938
# epoch#0 batch#18320 scenes#183200  avg loss per scene(past 100):  483.1619873046875 87.00973510742188
# epoch#0 batch#18340 scenes#183400  avg loss per scene(past 100):  159.8056640625 57.59687042236328
# epoch#0 batch#18360 scenes#183600  avg loss per scene(past 100):  81.31790161132812 133.32237243652344
# epoch#0 batch#18380 scenes#183800  avg loss per scene(past 100):  72.08032989501953 46.49476623535156
# epoch#0 batch#18400 scenes#184000  avg loss per scene(past 100):  91.00663757324219 53.56747055053711
# epoch#0 batch#18420 scenes#184200  avg loss per scene(past 100):  108.71440887451172 39.302345275878906
# epoch#0 batch#18440 scenes#184400  avg loss per scene(past 100):  81.90186309814453 63.886138916015625
# epoch#0 batch#18460 scenes#184600  avg loss per scene(past 100):  209.3727569580078 305.345703125
# epoch#0 batch#18480 scenes#184800  avg loss per scene(past 100):  131.25863647460938 75.20156860351562
# epoch#0 batch#18500 scenes#185000  avg loss per scene(past 100):  163.1807403564453 61.26152801513672
# epoch#0 batch#18520 scenes#185200  avg loss per scene(past 100):  85.0728759765625 56.70686340332031
# epoch#0 batch#18540 scenes#185400  avg loss per scene(past 100):  282.6312255859375 2127.348876953125
# epoch#0 batch#18560 scenes#185600  avg loss per scene(past 100):  322.90606689453125 110.52555084228516
# epoch#0 batch#18580 scenes#185800  avg loss per scene(past 100):  291.0874938964844 85.10625457763672
# epoch#0 batch#18600 scenes#186000  avg loss per scene(past 100):  117.11611938476562 43.552555084228516
# epoch#0 batch#18620 scenes#186200  avg loss per scene(past 100):  228.58871459960938 136.20181274414062
# epoch#0 batch#18640 scenes#186400  avg loss per scene(past 100):  353.4716796875 2199.864013671875
# epoch#0 batch#18660 scenes#186600  avg loss per scene(past 100):  105.5924072265625 77.66288757324219
# epoch#0 batch#18680 scenes#186800  avg loss per scene(past 100):  441.7350769042969 1438.923583984375
# epoch#0 batch#18700 scenes#187000  avg loss per scene(past 100):  335.76226806640625 74.63385009765625
# epoch#0 batch#18720 scenes#187200  avg loss per scene(past 100):  356.9765930175781 115.5957260131836
# epoch#0 batch#18740 scenes#187400  avg loss per scene(past 100):  177.47593688964844 165.11639404296875
# epoch#0 batch#18760 scenes#187600  avg loss per scene(past 100):  98.25151062011719 75.58528900146484
# epoch#0 batch#18780 scenes#187800  avg loss per scene(past 100):  72.73987579345703 41.910491943359375
# epoch#0 batch#18800 scenes#188000  avg loss per scene(past 100):  76.07310485839844 79.29827880859375
# epoch#0 batch#18820 scenes#188200  avg loss per scene(past 100):  71.84691619873047 61.152042388916016
# epoch#0 batch#18840 scenes#188400  avg loss per scene(past 100):  147.39659118652344 43.6843147277832
# epoch#0 batch#18860 scenes#188600  avg loss per scene(past 100):  220.6373291015625 80.68702697753906
# epoch#0 batch#18880 scenes#188800  avg loss per scene(past 100):  144.801025390625 84.57808685302734
# epoch#0 batch#18900 scenes#189000  avg loss per scene(past 100):  108.51419067382812 293.3028869628906
# epoch#0 batch#18920 scenes#189200  avg loss per scene(past 100):  70.51719665527344 156.89625549316406
# epoch#0 batch#18940 scenes#189400  avg loss per scene(past 100):  86.88072204589844 53.11872100830078
# epoch#0 batch#18960 scenes#189600  avg loss per scene(past 100):  134.56448364257812 67.50125122070312
# epoch#0 batch#18980 scenes#189800  avg loss per scene(past 100):  107.78205108642578 31.054157257080078
# epoch#0 batch#19000 scenes#190000  avg loss per scene(past 100):  82.21873474121094 38.97359848022461
# epoch#0 batch#19020 scenes#190200  avg loss per scene(past 100):  126.01964569091797 87.22327423095703
# epoch#0 batch#19040 scenes#190400  avg loss per scene(past 100):  3056.675537109375 437.9279479980469
# epoch#0 batch#19060 scenes#190600  avg loss per scene(past 100):  946.3102416992188 328.5642395019531
# epoch#0 batch#19080 scenes#190800  avg loss per scene(past 100):  411.5003967285156 216.0546112060547
# epoch#0 batch#19100 scenes#191000  avg loss per scene(past 100):  146.3701171875 96.29183959960938
# epoch#0 batch#19120 scenes#191200  avg loss per scene(past 100):  123.38653564453125 205.39422607421875
# epoch#0 batch#19140 scenes#191400  avg loss per scene(past 100):  88.59519958496094 70.4349594116211
# epoch#0 batch#19160 scenes#191600  avg loss per scene(past 100):  135.63925170898438 39.25563049316406
# epoch#0 batch#19180 scenes#191800  avg loss per scene(past 100):  86.72273254394531 44.01419448852539
# epoch#0 batch#19200 scenes#192000  avg loss per scene(past 100):  80.58641052246094 69.75932312011719
# epoch#0 batch#19220 scenes#192200  avg loss per scene(past 100):  73.13246154785156 55.838321685791016
# epoch#0 batch#19240 scenes#192400  avg loss per scene(past 100):  93.9116439819336 42.97770309448242
# epoch#0 batch#19260 scenes#192600  avg loss per scene(past 100):  281.47161865234375 65.13739013671875
# epoch#0 batch#19280 scenes#192800  avg loss per scene(past 100):  188.7137451171875 118.04130554199219
# epoch#0 batch#19300 scenes#193000  avg loss per scene(past 100):  85.21785736083984 59.548423767089844
# epoch#0 batch#19320 scenes#193200  avg loss per scene(past 100):  63.33995819091797 69.04407501220703
# epoch#0 batch#19340 scenes#193400  avg loss per scene(past 100):  282.8944091796875 76.24153900146484
# epoch#0 batch#19360 scenes#193600  avg loss per scene(past 100):  123.57319641113281 63.831764221191406
# epoch#0 batch#19380 scenes#193800  avg loss per scene(past 100):  86.27352905273438 41.219085693359375
# epoch#0 batch#19400 scenes#194000  avg loss per scene(past 100):  62.469215393066406 34.332359313964844
# epoch#0 batch#19420 scenes#194200  avg loss per scene(past 100):  521.0164184570312 48.79756164550781
# epoch#0 batch#19440 scenes#194400  avg loss per scene(past 100):  209.0002899169922 74.57072448730469
# epoch#0 batch#19460 scenes#194600  avg loss per scene(past 100):  438.4195556640625 3328.628173828125
# epoch#0 batch#19480 scenes#194800  avg loss per scene(past 100):  166.61160278320312 58.3245849609375
# epoch#0 batch#19500 scenes#195000  avg loss per scene(past 100):  91.66354370117188 106.79077911376953
# epoch#0 batch#19520 scenes#195200  avg loss per scene(past 100):  112.4952392578125 53.130592346191406
# epoch#0 batch#19540 scenes#195400  avg loss per scene(past 100):  105.23152160644531 52.788631439208984
# epoch#0 batch#19560 scenes#195600  avg loss per scene(past 100):  106.98313903808594 65.0907211303711
# epoch#0 batch#19580 scenes#195800  avg loss per scene(past 100):  70.10032653808594 50.823036193847656
# epoch#0 batch#19600 scenes#196000  avg loss per scene(past 100):  243.1287384033203 73.38434600830078
# epoch#0 batch#19620 scenes#196200  avg loss per scene(past 100):  230.11993408203125 77.6990737915039
# epoch#0 batch#19640 scenes#196400  avg loss per scene(past 100):  110.18807983398438 48.25632095336914
# epoch#0 batch#19660 scenes#196600  avg loss per scene(past 100):  178.177001953125 47.92903137207031
# epoch#0 batch#19680 scenes#196800  avg loss per scene(past 100):  282.2099914550781 41.95779037475586
# epoch#0 batch#19700 scenes#197000  avg loss per scene(past 100):  123.50572967529297 41.93190383911133
# epoch#0 batch#19720 scenes#197200  avg loss per scene(past 100):  82.89351654052734 34.512939453125
# epoch#0 batch#19740 scenes#197400  avg loss per scene(past 100):  143.42771911621094 137.0289764404297
# epoch#0 batch#19760 scenes#197600  avg loss per scene(past 100):  116.4769515991211 137.27432250976562
# epoch#0 batch#19780 scenes#197800  avg loss per scene(past 100):  86.83885955810547 114.54083251953125
# epoch#0 batch#19800 scenes#198000  avg loss per scene(past 100):  240.08932495117188 67.7737045288086
# epoch#0 batch#19820 scenes#198200  avg loss per scene(past 100):  119.66056823730469 55.939083099365234
# epoch#0 batch#19840 scenes#198400  avg loss per scene(past 100):  195.19595336914062 125.37928009033203
# epoch#0 batch#19860 scenes#198600  avg loss per scene(past 100):  494.24652099609375 120.57262420654297
# epoch#0 batch#19880 scenes#198800  avg loss per scene(past 100):  128.6215362548828 48.48271560668945
# epoch#0 batch#19900 scenes#199000  avg loss per scene(past 100):  101.4574203491211 71.70158386230469
# epoch#0 batch#19920 scenes#199200  avg loss per scene(past 100):  77.8748550415039 62.50831985473633
# epoch#0 batch#19940 scenes#199400  avg loss per scene(past 100):  352.83856201171875 193.05392456054688
# epoch#0 batch#19960 scenes#199600  avg loss per scene(past 100):  187.411865234375 75.9610824584961
# epoch#0 batch#19980 scenes#199800  avg loss per scene(past 100):  87.20500946044922 45.31086349487305
# epoch#0 batch#20000 scenes#200000  avg loss per scene(past 100):  105.05673217773438 60.45650100708008
# epoch#0 batch#20020 scenes#200200  avg loss per scene(past 100):  83.26534271240234 45.40287780761719
# epoch#0 batch#20040 scenes#200400  avg loss per scene(past 100):  53.26144027709961 62.807735443115234
# epoch#0 batch#20060 scenes#200600  avg loss per scene(past 100):  264.29559326171875 155.8441162109375
# epoch#0 batch#20080 scenes#200800  avg loss per scene(past 100):  111.33726501464844 74.31246948242188
# epoch#0 batch#20100 scenes#201000  avg loss per scene(past 100):  74.33576965332031 61.6187858581543
# epoch#0 batch#20120 scenes#201200  avg loss per scene(past 100):  84.06098937988281 38.66497802734375
# epoch#0 batch#20140 scenes#201400  avg loss per scene(past 100):  140.3336944580078 90.24275970458984
# epoch#0 batch#20160 scenes#201600  avg loss per scene(past 100):  202.10165405273438 99.32975769042969
# epoch#0 batch#20180 scenes#201800  avg loss per scene(past 100):  79.34767150878906 46.325035095214844
# epoch#0 batch#20200 scenes#202000  avg loss per scene(past 100):  98.10236358642578 55.912879943847656
# epoch#0 batch#20220 scenes#202200  avg loss per scene(past 100):  109.16290283203125 46.70762634277344
# epoch#0 batch#20240 scenes#202400  avg loss per scene(past 100):  176.25238037109375 43.199180603027344
# epoch#0 batch#20260 scenes#202600  avg loss per scene(past 100):  70.48506164550781 51.670772552490234
# epoch#0 batch#20280 scenes#202800  avg loss per scene(past 100):  109.98350524902344 42.46044921875
# epoch#0 batch#20300 scenes#203000  avg loss per scene(past 100):  112.27066802978516 99.42901611328125
# epoch#0 batch#20320 scenes#203200  avg loss per scene(past 100):  94.08152770996094 51.824729919433594
# epoch#0 batch#20340 scenes#203400  avg loss per scene(past 100):  65.65245056152344 44.60261535644531
# epoch#0 batch#20360 scenes#203600  avg loss per scene(past 100):  71.04100036621094 70.57196044921875
# epoch#0 batch#20380 scenes#203800  avg loss per scene(past 100):  73.47517395019531 67.21145629882812
# epoch#0 batch#20400 scenes#204000  avg loss per scene(past 100):  207.25851440429688 67.63932037353516
# epoch#0 batch#20420 scenes#204200  avg loss per scene(past 100):  84.94151306152344 93.43069458007812
# epoch#0 batch#20440 scenes#204400  avg loss per scene(past 100):  127.76536560058594 405.2793273925781
# epoch#0 batch#20460 scenes#204600  avg loss per scene(past 100):  102.28980255126953 59.35556411743164
# epoch#0 batch#20480 scenes#204800  avg loss per scene(past 100):  149.78369140625 38.60243606567383
# epoch#0 batch#20500 scenes#205000  avg loss per scene(past 100):  102.41251373291016 45.255149841308594
# epoch#0 batch#20520 scenes#205200  avg loss per scene(past 100):  679.2053833007812 151.06988525390625
# epoch#0 batch#20540 scenes#205400  avg loss per scene(past 100):  261.05615234375 84.3208999633789
# epoch#0 batch#20560 scenes#205600  avg loss per scene(past 100):  88.42021179199219 41.01085662841797
# epoch#0 batch#20580 scenes#205800  avg loss per scene(past 100):  61.37596130371094 46.49109649658203
# epoch#1 batch#0 scenes#0  avg loss per scene(past 100):  98.4553451538086 43.52861022949219
# epoch#1 batch#20 scenes#200  avg loss per scene(past 100):  188.4359893798828 1001.1284790039062
# epoch#1 batch#40 scenes#400  avg loss per scene(past 100):  151.14199829101562 337.56927490234375
# epoch#1 batch#60 scenes#600  avg loss per scene(past 100):  115.88836669921875 51.13855743408203
# epoch#1 batch#80 scenes#800  avg loss per scene(past 100):  85.79436492919922 53.70310592651367
# epoch#1 batch#100 scenes#1000  avg loss per scene(past 100):  134.00950622558594 262.690673828125
# epoch#1 batch#120 scenes#1200  avg loss per scene(past 100):  212.28677368164062 423.25823974609375
# epoch#1 batch#140 scenes#1400  avg loss per scene(past 100):  85.26468658447266 45.19837188720703
# epoch#1 batch#160 scenes#1600  avg loss per scene(past 100):  133.8661346435547 60.41136932373047
# epoch#1 batch#180 scenes#1800  avg loss per scene(past 100):  210.53933715820312 530.7188720703125
# epoch#1 batch#200 scenes#2000  avg loss per scene(past 100):  90.63593292236328 47.182701110839844
# epoch#1 batch#220 scenes#2200  avg loss per scene(past 100):  91.47570037841797 82.45252990722656
# epoch#1 batch#240 scenes#2400  avg loss per scene(past 100):  99.7039794921875 45.230369567871094
# epoch#1 batch#260 scenes#2600  avg loss per scene(past 100):  78.09635925292969 42.35175323486328
# epoch#1 batch#280 scenes#2800  avg loss per scene(past 100):  80.22718048095703 39.47855758666992
# epoch#1 batch#300 scenes#3000  avg loss per scene(past 100):  85.45281219482422 49.54087448120117
# epoch#1 batch#320 scenes#3200  avg loss per scene(past 100):  630.1581420898438 5010.88134765625
# epoch#1 batch#340 scenes#3400  avg loss per scene(past 100):  224.32501220703125 102.54715728759766
# epoch#1 batch#360 scenes#3600  avg loss per scene(past 100):  168.927490234375 52.89236068725586
# epoch#1 batch#380 scenes#3800  avg loss per scene(past 100):  91.41670989990234 143.0942840576172
# epoch#1 batch#400 scenes#4000  avg loss per scene(past 100):  120.16478729248047 62.17827224731445
# epoch#1 batch#420 scenes#4200  avg loss per scene(past 100):  155.99929809570312 93.63727569580078

# %%
torch.save(model.state_dict(), './FCM_Adam_30Epochs_HDim7k_L2.pth')

# %%
import numpy as np
# import pandas as pd

save_file = "FCM_Adam_30Epochs_HDim7k_L2.csv"


header = ["ID"]
header += ["v"+str(x) for x in range(1, 61)]
print(header)

with open(save_file, 'w') as f:
    f.write(",".join(header)+"\n")

device = "cuda:0"

testmodel = FullyConnectedModel()
testmodel.load_state_dict(torch.load('FCM_Adam_30Epochs_HDim7k_L2.pth'))
testmodel.to(device)
testmodel.eval()

full_out = []
print("test")
varMaxOutput= [4773.,   4097.7,   193.19,  194.33]
varMinOutput=[ -53.912,    0.,    -210.04,  -187.71 ]
#         #Changed to 4 because we don't need lane and lane norm
batch_sz = 2
     
for i_batch, sample_batch in enumerate(val_loader):
    if i_batch % 100 == 0:
        print("batch #: ", i_batch * batch_sz)

    inp, scene_idx, agent_ids, track_ids,laneInfo,city = sample_batch
    city = city.cuda()
    laneInfo = laneInfo.cuda()
    inp = inp.cuda()

    mixed = torch.cat([city,laneInfo,inp],2).transpose(1,2).reshape(-1,39,4 * 60).reshape(-1,39*240)
    y_pred = testmodel(mixed)
    y_pred = y_pred.reshape((-1,30,60,4)).transpose(1,2)
    

    i_scene = 0
    out = []
    for ag_id in agent_ids:
        nestedTrackIds = track_ids[i_scene]
        j = 0
        for track_id in nestedTrackIds:

            if ag_id == track_id[0]:
                out.append(y_pred[i_scene][j][:,:2].reshape(60))
            j+=1
        i_scene+=1
                           
 

    with open(save_file, "a") as f:
        for i_scene in range(len(out)):
#             realOut = out[i].eval(session=tf.compat.v1.Session())
            array = out[i_scene]
#             print(out[i][0])
            row = ','.join([str(element.item()) for element in array])
            f.write(str(scene_idx[i_scene])+"," + row +"\n")
# Out:
# ['ID', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10', 'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20', 'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'v29', 'v30', 'v31', 'v32', 'v33', 'v34', 'v35', 'v36', 'v37', 'v38', 'v39', 'v40', 'v41', 'v42', 'v43', 'v44', 'v45', 'v46', 'v47', 'v48', 'v49', 'v50', 'v51', 'v52', 'v53', 'v54', 'v55', 'v56', 'v57', 'v58', 'v59', 'v60']
# test
# batch #:  0
# batch #:  200
# batch #:  400
# batch #:  600
# batch #:  800
# batch #:  1000
# batch #:  1200
# batch #:  1400
# batch #:  1600
# batch #:  1800
# batch #:  2000
# batch #:  2200
# batch #:  2400
# batch #:  2600
# batch #:  2800
# batch #:  3000
